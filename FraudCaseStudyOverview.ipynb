# %% [markdown]
# # Fraud case study

# %% [markdown]
# ## Day 1: building a fraud model

# %% [markdown]
# ## Day 2: building an app/dashboard

# %% [markdown]
# ## Tips success
#
# You will quickly run out of time:
#
# *  Use CRISP-DM workflow to analyze data and build a model
# *  Iterate quickly, test often, commit often
# *  Build deadlines for your work so you stay on track
# *  Should have a model by end of day 1
# *  Start app once model is working

# %% [markdown]
# ### CRISP-DM workflow
#
# Follow the [CRISP-DM](https://en.wikipedia.org/wiki/Cross_Industry_Standard_Process_for_Data_Mining) steps:
#
# 1.  Business understanding
# 2.  Data understanding
# 3.  Data preparation
# 4.  Modeling
# 5.  Evaluation
# 6.  Deployment

# %% [markdown]
# # Introduction to case study: data & problem

# %% [markdown]
# Let's look at the data.  What format is the data in?  How do you extract it?

# %%
ls -lh data
# Out:
# total 67280
# -rw-r--r--  1 jbud  staff    33M May 27 20:23 data.zip

# %% [markdown]
# Unzip the data so you can load it into Python

# %%
# !unzip data/data.zip -d data
# Out:
# Archive:  data/data.zip
#   inflating: data/data.json

# %% [markdown]
# Initially, work with a subset at first in order to iterate quickly.  But, the file is one giant line of json:

# %%
# !wc data/data.json
# Out:
#        0 8173151 250481668 data/data.json

# %% [markdown]
# Write a quick and dirty script to pull out the first 100 records so we can get code working quickly.

# %%
# %%writefile subset_json.py
"""head_json.py - extract a couple records from a huge json file.

Syntax: python head_json.py < infile.json > outfile.json
"""

import sys

start_char = '{'
stop_char = '}'
n_records = 100
level_nesting = 0

while n_records != 0:
    ch = sys.stdin.read(1)
    sys.stdout.write(ch)
    if ch == start_char:
        level_nesting += 1
    if ch == stop_char:
        level_nesting -= 1
        if level_nesting == 0:
            n_records -= 1
sys.stdout.write(']')
# Out:
# Writing subset_json.py

# %%
# !python subset_json.py < data/data.json > data/subset.json

# %%
import pandas as pd

df = pd.read_json('data/subset.json')

# %%
df.info
# Out:
# <bound method DataFrame.info of           acct_type  approx_payout_date  body_length  channels country  \
# 0   fraudster_event          1266062400         3852         5      US
# 1           premium          1296720000         3499         0      US
# 2           premium          1296172800         2601         8      US
# 3           premium          1388966400        12347         6      IE
# 4           premium          1297900800         2417        11      US
# ..              ...                 ...          ...       ...     ...
# 95          premium          1328070600         1314         6      US
# 96          premium          1324098000         1483         6      US
# 97          premium          1325844000         1860         5      US
# 98          premium          1325836500         2219        11      US
# 99          premium          1357466400        12479         8      US
#
#    currency  delivery_method  \
# 0       USD                0
# 1       USD                1
# 2       USD                1
# 3       EUR                1
# 4       USD                0
# ..      ...              ...
# 95      USD                0
# 96      USD                0
# 97      USD                1
# 98      USD                1
# 99      USD                0
#
#                                           description  \
# 0   <p><a href="http://s432.photobucket.com/albums...
# 1   <p>Join us for a quick, one-night, community-b...
# 2   <h3><span class="subcategory"><strong>Teacher ...
# 3   <p style="margin-bottom: 1.3em; padding-bottom...
# 4   <p>Writers and filmmakers need to understand t...
# ..                                                ...
# 95  <h3>Jan 26 at 7pm</h3>\r\n<h4>Opening Night Ga...
# 96  <p> </p>\r\n<div style="text-align: -webkit-au...
# 97  <p style="text-align: center;"><span style="fo...
# 98  <p style="font-size: 10pt;" align="left"><img ...
# 99  <p class="MsoNormal" style="text-align: center...
#
#                   email_domain  event_created  ...  \
# 0                    gmail.com     1262739706  ...
# 1                      ruf.org     1293832670  ...
# 2               pvsd.k12.ca.us     1291090956  ...
# 3         irishtabletennis.com     1360681570  ...
# 4   artsandbusinesscouncil.org     1291994666  ...
# ..                         ...            ...  ...
# 95             nwfilmforum.org     1322877746  ...
# 96         richmondicezone.com     1322879399  ...
# 97           kineticevents.com     1323477465  ...
# 98                   cecnc.com     1325106030  ...
# 99                     aol.com     1352996234  ...
#
#                                          ticket_types  user_age  user_created  \
# 0   [{'event_id': 527017, 'cost': 25.0, 'availabil...        36    1259613950
# 1   [{'event_id': 786878, 'cost': 35.0, 'availabil...       149    1280942776
# 2   [{'event_id': 787337, 'cost': 93.51, 'availabi...       214    1272559388
# 3   [{'event_id': 885645, 'cost': 25.0, 'availabil...       889    1283870102
# 4   [{'event_id': 1114349, 'cost': 150.0, 'availab...        35    1288984065
# ..                                                ...       ...           ...
# 95  [{'event_id': 2589534, 'cost': 38.0, 'availabi...       211    1304619530
# 96  [{'event_id': 2589614, 'cost': 8.0, 'availabil...       682    1263930774
# 97  [{'event_id': 2621588, 'cost': 20.0, 'availabi...       359    1292438475
# 98  [{'event_id': 2687671, 'cost': 0.0, 'availabil...       919    1245718455
# 99  [{'event_id': 2687765, 'cost': 20.0, 'availabi...      1103    1257709022
#
#     user_type                 venue_address  venue_country  venue_latitude  \
# 0           1         717 Washington Avenue             US       25.777471
# 1           3                                           US       32.776566
# 2           3  10100 Pioneer Blvd Suite 100             US       33.944201
# 3           3                                         None             NaN
# 4           3        One Marina Park Drive              US       42.353848
# ..        ...                           ...            ...             ...
# 95          3             1515 12th Avenue              US       47.614380
# 96          4       4350 Pouncey Tract Road             US       37.654891
# 97          1                 138 Minna St.             US       37.786823
# 98          3                  111 Minna St             US       37.787429
# 99          4     58 ROSS WAY QUINCY CENTER             US       42.247811
#
#     venue_longitude                              venue_name venue_state
# 0        -80.133433             INK Nightclub - South Beach          FL
# 1        -79.930922                 The Charleston, SC area          SC
# 2       -118.080419  Los Angeles County Office of Education          CA
# 3               NaN                                    None        None
# 4        -71.044276                       Fish & Richardson          MA
# ..              ...                                     ...         ...
# 95      -122.317031                   Northwest Film Forum           WA
# 96       -77.613550                        SkateNation Plus          VA
# 97      -122.400339                             John Colins          CA
# 98      -122.399384                       111 Minna Gallery          CA
# 99       -71.001400           CLUB 58 ENTERTAINMENT COMPLEX          MA
#
# [100 rows x 44 columns]>

# %%
df.head().T
# Out:
#                                                                     0  \
# acct_type                                             fraudster_event
# approx_payout_date                                         1266062400
# body_length                                                      3852
# channels                                                            5
# country                                                            US
# currency                                                          USD
# delivery_method                                                     0
# description         <p><a href="http://s432.photobucket.com/albums...
# email_domain                                                gmail.com
# event_created                                              1262739706
# event_end                                                  1265630400
# event_published                                            1263109838
# event_start                                                1265594400
# fb_published                                                        0
# gts                                                                 0
# has_analytics                                                       0
# has_header                                                          1
# has_logo                                                            0
# listed                                                              y
# name                99 HOUR "NO SLEEP" SUPER BOWL CELEBRITY WEEKEN...
# name_length                                                        60
# num_order                                                           0
# num_payouts                                                         0
# object_id                                                      527017
# org_desc
# org_facebook                                                        0
# org_name                        Party Starz Ent & Diverse Int'l Group
# org_twitter                                                         0
# payee_name
# payout_type
# previous_payouts                                                   []
# sale_duration                                                      29
# sale_duration2                                                     33
# show_map                                                            1
# ticket_types        [{'event_id': 527017, 'cost': 25.0, 'availabil...
# user_age                                                           36
# user_created                                               1259613950
# user_type                                                           1
# venue_address                                   717 Washington Avenue
# venue_country                                                      US
# venue_latitude                                                25.7775
# venue_longitude                                              -80.1334
# venue_name                                INK Nightclub - South Beach
# venue_state                                                        FL
#
#                                                                     1  \
# acct_type                                                     premium
# approx_payout_date                                         1296720000
# body_length                                                      3499
# channels                                                            0
# country                                                            US
# currency                                                          USD
# delivery_method                                                     1
# description         <p>Join us for a quick, one-night, community-b...
# email_domain                                                  ruf.org
# event_created                                              1293832670
# event_end                                                  1296288000
# event_published                                            1293833295
# event_start                                                1296255600
# fb_published                                                        0
# gts                                                            868.02
# has_analytics                                                       0
# has_header                                                          0
# has_logo                                                            1
# listed                                                              n
# name                                      Winthrop RUF Winter Getaway
# name_length                                                        27
# num_order                                                          23
# num_payouts                                                         1
# object_id                                                      786878
# org_desc            <p>Since 1987, RUF has ministered to students ...
# org_facebook                                                        0
# org_name                                   RUF at Winthrop University
# org_twitter                                                        12
# payee_name                                                        RUF
# payout_type                                                     CHECK
# previous_payouts    [{'name': 'RUF', 'created': '2010-10-01 01:10:...
# sale_duration                                                      28
# sale_duration2                                                     28
# show_map                                                            0
# ticket_types        [{'event_id': 786878, 'cost': 35.0, 'availabil...
# user_age                                                          149
# user_created                                               1280942776
# user_type                                                           3
# venue_address
# venue_country                                                      US
# venue_latitude                                                32.7766
# venue_longitude                                              -79.9309
# venue_name                                    The Charleston, SC area
# venue_state                                                        SC
#
#                                                                     2  \
# acct_type                                                     premium
# approx_payout_date                                         1296172800
# body_length                                                      2601
# channels                                                            8
# country                                                            US
# currency                                                          USD
# delivery_method                                                     1
# description         <h3><span class="subcategory"><strong>Teacher ...
# email_domain                                           pvsd.k12.ca.us
# event_created                                              1291090956
# event_end                                                  1295740800
# event_published                                            1291091908
# event_start                                                1295713800
# fb_published                                                        0
# gts                                                              3500
# has_analytics                                                       0
# has_header                                                        NaN
# has_logo                                                            0
# listed                                                              y
# name                                     DRDP (2010) Teacher Training
# name_length                                                        28
# num_order                                                          19
# num_payouts                                                         4
# object_id                                                      787337
# org_desc            <p><a href="http://www.desiredresults.com">www...
# org_facebook                                                        0
# org_name            University Preparation School in collaboration...
# org_twitter                                                         0
# payee_name                              University Preparation School
# payout_type                                                     CHECK
# previous_payouts    [{'name': 'Danielle Severn', 'created': '2010-...
# sale_duration                                                      54
# sale_duration2                                                     54
# show_map                                                            0
# ticket_types        [{'event_id': 787337, 'cost': 93.51, 'availabi...
# user_age                                                          214
# user_created                                               1272559388
# user_type                                                           3
# venue_address                            10100 Pioneer Blvd Suite 100
# venue_country                                                      US
# venue_latitude                                                33.9442
# venue_longitude                                               -118.08
# venue_name                     Los Angeles County Office of Education
# venue_state                                                        CA
#
#                                                                     3  \
# acct_type                                                     premium
# approx_payout_date                                         1388966400
# body_length                                                     12347
# channels                                                            6
# country                                                            IE
# currency                                                          EUR
# delivery_method                                                     1
# description         <p style="margin-bottom: 1.3em; padding-bottom...
# email_domain                                     irishtabletennis.com
# event_created                                              1360681570
# event_end                                                  1388534400
# event_published                                            1360683446
# event_start                                                1360702800
# fb_published                                                        0
# gts                                                           1167.35
# has_analytics                                                       0
# has_header                                                          0
# has_logo                                                            1
# listed                                                              y
# name                                            ITTA Affiliation 2013
# name_length                                                        21
# num_order                                                          39
# num_payouts                                                        16
# object_id                                                      885645
# org_desc
# org_facebook                                                        0
# org_name
# org_twitter                                                         0
# payee_name
# payout_type                                                       ACH
# previous_payouts    [{'name': '', 'created': '2010-11-09 01:10:15'...
# sale_duration                                                       0
# sale_duration2                                                      0
# show_map                                                            0
# ticket_types        [{'event_id': 885645, 'cost': 25.0, 'availabil...
# user_age                                                          889
# user_created                                               1283870102
# user_type                                                           3
# venue_address
# venue_country                                                    None
# venue_latitude                                                    NaN
# venue_longitude                                                   NaN
# venue_name                                                       None
# venue_state                                                      None
#
#                                                                     4
# acct_type                                                     premium
# approx_payout_date                                         1297900800
# body_length                                                      2417
# channels                                                           11
# country                                                            US
# currency                                                          USD
# delivery_method                                                     0
# description         <p>Writers and filmmakers need to understand t...
# email_domain                               artsandbusinesscouncil.org
# event_created                                              1291994666
# event_end                                                  1297468800
# event_published                                            1291994966
# event_start                                                1297440000
# fb_published                                                        1
# gts                                                           2313.15
# has_analytics                                                       0
# has_header                                                          0
# has_logo                                                            0
# listed                                                              y
# name                Self Defense for Writers and Filmmakers: For A...
# name_length                                                        66
# num_order                                                          30
# num_payouts                                                         0
# object_id                                                     1114349
# org_desc            <p><font face="Arial"><font size="2"><strong>T...
# org_facebook                                                        0
# org_name                   Arts & Business Council of Greater Boston
# org_twitter                                                         0
# payee_name                Arts and Business Council or Greater Boston
# payout_type                                                     CHECK
# previous_payouts    [{'name': 'Arts and Business Council or Greate...
# sale_duration                                                      63
# sale_duration2                                                     63
# show_map                                                            0
# ticket_types        [{'event_id': 1114349, 'cost': 150.0, 'availab...
# user_age                                                           35
# user_created                                               1288984065
# user_type                                                           3
# venue_address                                  One Marina Park Drive
# venue_country                                                      US
# venue_latitude                                                42.3538
# venue_longitude                                              -71.0443
# venue_name                                          Fish & Richardson
# venue_state                                                        MA

# %% [markdown]
# Some of the data is text (and HTML), which will require feature engineering:
#
# * TF-IDF
# * Feature hashing
# * n-grams
#
# etc.
#
# You will also need to construct a target from `acct_type`.  Fraud events start with `fraud`.  How you define fraud depends on how you define the business problem.

# %%
df.acct_type.value_counts(dropna=False)
# Out:
# premium             90
# fraudster            3
# spammer_warn         3
# fraudster_event      2
# spammer_noinvite     1
# spammer_limited      1
# Name: acct_type, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 44 columns):
# acct_type             100 non-null object
# approx_payout_date    100 non-null int64
# body_length           100 non-null int64
# channels              100 non-null int64
# country               100 non-null object
# currency              100 non-null object
# delivery_method       100 non-null int64
# description           100 non-null object
# email_domain          100 non-null object
# event_created         100 non-null int64
# event_end             100 non-null int64
# event_published       100 non-null int64
# event_start           100 non-null int64
# fb_published          100 non-null int64
# gts                   100 non-null float64
# has_analytics         100 non-null int64
# has_header            90 non-null float64
# has_logo              100 non-null int64
# listed                100 non-null object
# name                  100 non-null object
# name_length           100 non-null int64
# num_order             100 non-null int64
# num_payouts           100 non-null int64
# object_id             100 non-null int64
# org_desc              100 non-null object
# org_facebook          100 non-null int64
# org_name              100 non-null object
# org_twitter           100 non-null int64
# payee_name            100 non-null object
# payout_type           100 non-null object
# previous_payouts      100 non-null object
# sale_duration         100 non-null int64
# sale_duration2        100 non-null int64
# show_map              100 non-null int64
# ticket_types          100 non-null object
# user_age              100 non-null int64
# user_created          100 non-null int64
# user_type             100 non-null int64
# venue_address         100 non-null object
# venue_country         93 non-null object
# venue_latitude        93 non-null float64
# venue_longitude       93 non-null float64
# venue_name            93 non-null object
# venue_state           93 non-null object
# dtypes: float64(4), int64(23), object(17)
# memory usage: 34.5+ KB

# %% [markdown]
# Is missing data a problem?  What are your options for handling missing data?

# %%
df.describe().T
# Out:
#                     count          mean           std           min  \
# approx_payout_date  100.0  1.314867e+09  1.455055e+07  1.266062e+09
# body_length         100.0  3.114250e+03  2.814620e+03  0.000000e+00
# channels            100.0  7.500000e+00  3.195641e+00  0.000000e+00
# delivery_method     100.0  4.600000e-01  6.100174e-01  0.000000e+00
# event_created       100.0  1.309823e+09  1.272655e+07  1.262740e+09
# event_end           100.0  1.314436e+09  1.455050e+07  1.265630e+09
# event_published     100.0  1.310264e+09  1.282619e+07  1.263110e+09
# event_start         100.0  1.314038e+09  1.330579e+07  1.265594e+09
# fb_published        100.0  2.000000e-01  4.020151e-01  0.000000e+00
# gts                 100.0  2.223905e+03  5.168755e+03  0.000000e+00
# has_analytics       100.0  1.000000e-01  3.015113e-01  0.000000e+00
# has_header           90.0  1.888889e-01  3.936132e-01  0.000000e+00
# has_logo            100.0  8.800000e-01  3.265986e-01  0.000000e+00
# name_length         100.0  4.692000e+01  3.332778e+01  7.000000e+00
# num_order           100.0  3.192000e+01  6.707296e+01  0.000000e+00
# num_payouts         100.0  3.630000e+01  1.442187e+02  0.000000e+00
# object_id           100.0  1.845388e+06  5.169876e+05  5.270170e+05
# org_facebook        100.0  6.580000e+00  1.059844e+01  0.000000e+00
# org_twitter         100.0  4.400000e+00  6.177509e+00  0.000000e+00
# sale_duration       100.0  4.359000e+01  4.449245e+01  0.000000e+00
# sale_duration2      100.0  4.866000e+01  4.645976e+01  0.000000e+00
# show_map            100.0  6.300000e-01  4.852366e-01  0.000000e+00
# user_age            100.0  3.207900e+02  3.060931e+02  0.000000e+00
# user_created        100.0  1.282107e+09  2.657472e+07  1.216722e+09
# user_type           100.0  2.850000e+00  9.679198e-01  1.000000e+00
# venue_latitude       93.0  3.754351e+01  1.357540e+01 -3.776669e+01
# venue_longitude      93.0 -7.787352e+01  5.028441e+01 -1.231114e+02
#
#                              25%           50%           75%           max
# approx_payout_date  1.304711e+09  1.315984e+09  1.322812e+09  1.388966e+09
# body_length         1.077500e+03  1.920500e+03  4.361000e+03  1.247900e+04
# channels            5.750000e+00  8.000000e+00  1.100000e+01  1.300000e+01
# delivery_method     0.000000e+00  0.000000e+00  1.000000e+00  3.000000e+00
# event_created       1.300009e+09  1.310730e+09  1.318629e+09  1.360682e+09
# event_end           1.304279e+09  1.315552e+09  1.322380e+09  1.388534e+09
# event_published     1.300033e+09  1.312086e+09  1.318995e+09  1.360683e+09
# event_start         1.304267e+09  1.315433e+09  1.321645e+09  1.360703e+09
# fb_published        0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# gts                 9.998500e+01  5.595900e+02  1.451150e+03  3.896353e+04
# has_analytics       0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# has_header          0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# has_logo            1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# name_length         2.700000e+01  4.250000e+01  5.700000e+01  2.540000e+02
# num_order           2.000000e+00  1.100000e+01  2.525000e+01  4.020000e+02
# num_payouts         0.000000e+00  1.500000e+00  1.075000e+01  1.034000e+03
# object_id           1.376994e+06  1.900935e+06  2.261382e+06  2.687765e+06
# org_facebook        0.000000e+00  0.000000e+00  1.125000e+01  4.800000e+01
# org_twitter         0.000000e+00  0.000000e+00  1.100000e+01  1.600000e+01
# sale_duration       1.875000e+01  3.200000e+01  5.525000e+01  2.810000e+02
# sale_duration2      2.000000e+01  3.550000e+01  6.125000e+01  2.810000e+02
# show_map            0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# user_age            6.050000e+01  2.460000e+02  4.635000e+02  1.185000e+03
# user_created        1.264654e+09  1.285645e+09  1.302947e+09  1.322086e+09
# user_type           3.000000e+00  3.000000e+00  3.000000e+00  5.000000e+00
# venue_latitude      3.471241e+01  3.889863e+01  4.235385e+01  5.346135e+01
# venue_longitude    -1.180804e+02 -8.264348e+01 -7.331744e+01  1.536130e+02

# %%
df
# Out:
#           acct_type  approx_payout_date  body_length  channels country  \
# 0   fraudster_event          1266062400         3852         5      US
# 1           premium          1296720000         3499         0      US
# 2           premium          1296172800         2601         8      US
# 3           premium          1388966400        12347         6      IE
# 4           premium          1297900800         2417        11      US
# ..              ...                 ...          ...       ...     ...
# 95          premium          1328070600         1314         6      US
# 96          premium          1324098000         1483         6      US
# 97          premium          1325844000         1860         5      US
# 98          premium          1325836500         2219        11      US
# 99          premium          1357466400        12479         8      US
#
#    currency  delivery_method  \
# 0       USD                0
# 1       USD                1
# 2       USD                1
# 3       EUR                1
# 4       USD                0
# ..      ...              ...
# 95      USD                0
# 96      USD                0
# 97      USD                1
# 98      USD                1
# 99      USD                0
#
#                                           description  \
# 0   <p><a href="http://s432.photobucket.com/albums...
# 1   <p>Join us for a quick, one-night, community-b...
# 2   <h3><span class="subcategory"><strong>Teacher ...
# 3   <p style="margin-bottom: 1.3em; padding-bottom...
# 4   <p>Writers and filmmakers need to understand t...
# ..                                                ...
# 95  <h3>Jan 26 at 7pm</h3>\r\n<h4>Opening Night Ga...
# 96  <p> </p>\r\n<div style="text-align: -webkit-au...
# 97  <p style="text-align: center;"><span style="fo...
# 98  <p style="font-size: 10pt;" align="left"><img ...
# 99  <p class="MsoNormal" style="text-align: center...
#
#                   email_domain  event_created  ...  \
# 0                    gmail.com     1262739706  ...
# 1                      ruf.org     1293832670  ...
# 2               pvsd.k12.ca.us     1291090956  ...
# 3         irishtabletennis.com     1360681570  ...
# 4   artsandbusinesscouncil.org     1291994666  ...
# ..                         ...            ...  ...
# 95             nwfilmforum.org     1322877746  ...
# 96         richmondicezone.com     1322879399  ...
# 97           kineticevents.com     1323477465  ...
# 98                   cecnc.com     1325106030  ...
# 99                     aol.com     1352996234  ...
#
#                                          ticket_types  user_age  user_created  \
# 0   [{'event_id': 527017, 'cost': 25.0, 'availabil...        36    1259613950
# 1   [{'event_id': 786878, 'cost': 35.0, 'availabil...       149    1280942776
# 2   [{'event_id': 787337, 'cost': 93.51, 'availabi...       214    1272559388
# 3   [{'event_id': 885645, 'cost': 25.0, 'availabil...       889    1283870102
# 4   [{'event_id': 1114349, 'cost': 150.0, 'availab...        35    1288984065
# ..                                                ...       ...           ...
# 95  [{'event_id': 2589534, 'cost': 38.0, 'availabi...       211    1304619530
# 96  [{'event_id': 2589614, 'cost': 8.0, 'availabil...       682    1263930774
# 97  [{'event_id': 2621588, 'cost': 20.0, 'availabi...       359    1292438475
# 98  [{'event_id': 2687671, 'cost': 0.0, 'availabil...       919    1245718455
# 99  [{'event_id': 2687765, 'cost': 20.0, 'availabi...      1103    1257709022
#
#     user_type                 venue_address  venue_country  venue_latitude  \
# 0           1         717 Washington Avenue             US       25.777471
# 1           3                                           US       32.776566
# 2           3  10100 Pioneer Blvd Suite 100             US       33.944201
# 3           3                                         None             NaN
# 4           3        One Marina Park Drive              US       42.353848
# ..        ...                           ...            ...             ...
# 95          3             1515 12th Avenue              US       47.614380
# 96          4       4350 Pouncey Tract Road             US       37.654891
# 97          1                 138 Minna St.             US       37.786823
# 98          3                  111 Minna St             US       37.787429
# 99          4     58 ROSS WAY QUINCY CENTER             US       42.247811
#
#     venue_longitude                              venue_name venue_state
# 0        -80.133433             INK Nightclub - South Beach          FL
# 1        -79.930922                 The Charleston, SC area          SC
# 2       -118.080419  Los Angeles County Office of Education          CA
# 3               NaN                                    None        None
# 4        -71.044276                       Fish & Richardson          MA
# ..              ...                                     ...         ...
# 95      -122.317031                   Northwest Film Forum           WA
# 96       -77.613550                        SkateNation Plus          VA
# 97      -122.400339                             John Colins          CA
# 98      -122.399384                       111 Minna Gallery          CA
# 99       -71.001400           CLUB 58 ENTERTAINMENT COMPLEX          MA
#
# [100 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['acct_type', 'approx_payout_date', 'body_length', 'channels', 'country',
#        'currency', 'delivery_method', 'description', 'email_domain',
#        'event_created', 'event_end', 'event_published', 'event_start',
#        'fb_published', 'gts', 'has_analytics', 'has_header', 'has_logo',
#        'listed', 'name', 'name_length', 'num_order', 'num_payouts',
#        'object_id', 'org_desc', 'org_facebook', 'org_name', 'org_twitter',
#        'payee_name', 'payout_type', 'previous_payouts', 'sale_duration',
#        'sale_duration2', 'show_map', 'ticket_types', 'user_age',
#        'user_created', 'user_type', 'venue_address', 'venue_country',
#        'venue_latitude', 'venue_longitude', 'venue_name', 'venue_state'],
#       dtype='object')

# %%
column_subset = ['acct_type','has_analytics', 'has_header', 'has_logo',
       'listed', 'name', 'name_length', 'num_order', 'num_payouts',
       'object_id', 'org_desc', 'org_facebook', 'org_name', 'org_twitter',
       'payee_name', 'payout_type']

# %%
df['acct_type'].unique()
# Out:
# array(['fraudster_event', 'premium', 'spammer_warn', 'fraudster',
#        'spammer_limited', 'spammer_noinvite'], dtype=object)

# %%
df
# Out:
#     acct_type  approx_payout_date  body_length  channels country currency  \
# 0        True          1266062400         3852         5      US      USD
# 1       False          1296720000         3499         0      US      USD
# 2       False          1296172800         2601         8      US      USD
# 3       False          1388966400        12347         6      IE      EUR
# 4       False          1297900800         2417        11      US      USD
# ..        ...                 ...          ...       ...     ...      ...
# 95      False          1328070600         1314         6      US      USD
# 96      False          1324098000         1483         6      US      USD
# 97      False          1325844000         1860         5      US      USD
# 98      False          1325836500         2219        11      US      USD
# 99      False          1357466400        12479         8      US      USD
#
#     delivery_method                                        description  \
# 0                 0  <p><a href="http://s432.photobucket.com/albums...
# 1                 1  <p>Join us for a quick, one-night, community-b...
# 2                 1  <h3><span class="subcategory"><strong>Teacher ...
# 3                 1  <p style="margin-bottom: 1.3em; padding-bottom...
# 4                 0  <p>Writers and filmmakers need to understand t...
# ..              ...                                                ...
# 95                0  <h3>Jan 26 at 7pm</h3>\r\n<h4>Opening Night Ga...
# 96                0  <p> </p>\r\n<div style="text-align: -webkit-au...
# 97                1  <p style="text-align: center;"><span style="fo...
# 98                1  <p style="font-size: 10pt;" align="left"><img ...
# 99                0  <p class="MsoNormal" style="text-align: center...
#
#                   email_domain  event_created  ...  \
# 0                    gmail.com     1262739706  ...
# 1                      ruf.org     1293832670  ...
# 2               pvsd.k12.ca.us     1291090956  ...
# 3         irishtabletennis.com     1360681570  ...
# 4   artsandbusinesscouncil.org     1291994666  ...
# ..                         ...            ...  ...
# 95             nwfilmforum.org     1322877746  ...
# 96         richmondicezone.com     1322879399  ...
# 97           kineticevents.com     1323477465  ...
# 98                   cecnc.com     1325106030  ...
# 99                     aol.com     1352996234  ...
#
#                                          ticket_types  user_age  user_created  \
# 0   [{'event_id': 527017, 'cost': 25.0, 'availabil...        36    1259613950
# 1   [{'event_id': 786878, 'cost': 35.0, 'availabil...       149    1280942776
# 2   [{'event_id': 787337, 'cost': 93.51, 'availabi...       214    1272559388
# 3   [{'event_id': 885645, 'cost': 25.0, 'availabil...       889    1283870102
# 4   [{'event_id': 1114349, 'cost': 150.0, 'availab...        35    1288984065
# ..                                                ...       ...           ...
# 95  [{'event_id': 2589534, 'cost': 38.0, 'availabi...       211    1304619530
# 96  [{'event_id': 2589614, 'cost': 8.0, 'availabil...       682    1263930774
# 97  [{'event_id': 2621588, 'cost': 20.0, 'availabi...       359    1292438475
# 98  [{'event_id': 2687671, 'cost': 0.0, 'availabil...       919    1245718455
# 99  [{'event_id': 2687765, 'cost': 20.0, 'availabi...      1103    1257709022
#
#     user_type                 venue_address  venue_country  venue_latitude  \
# 0           1         717 Washington Avenue             US       25.777471
# 1           3                                           US       32.776566
# 2           3  10100 Pioneer Blvd Suite 100             US       33.944201
# 3           3                                         None             NaN
# 4           3        One Marina Park Drive              US       42.353848
# ..        ...                           ...            ...             ...
# 95          3             1515 12th Avenue              US       47.614380
# 96          4       4350 Pouncey Tract Road             US       37.654891
# 97          1                 138 Minna St.             US       37.786823
# 98          3                  111 Minna St             US       37.787429
# 99          4     58 ROSS WAY QUINCY CENTER             US       42.247811
#
#     venue_longitude                              venue_name venue_state
# 0        -80.133433             INK Nightclub - South Beach          FL
# 1        -79.930922                 The Charleston, SC area          SC
# 2       -118.080419  Los Angeles County Office of Education          CA
# 3               NaN                                    None        None
# 4        -71.044276                       Fish & Richardson          MA
# ..              ...                                     ...         ...
# 95      -122.317031                   Northwest Film Forum           WA
# 96       -77.613550                        SkateNation Plus          VA
# 97      -122.400339                             John Colins          CA
# 98      -122.399384                       111 Minna Gallery          CA
# 99       -71.001400           CLUB 58 ENTERTAINMENT COMPLEX          MA
#
# [100 rows x 44 columns]

# %%
df = pd.read_json('data/subset.json')

# %%
#Payout date - relation to 

def is_fraud(df, col):
    '''
    Replaces fraud with 1 for true, 0 for false
    '''
    fraud_descriptors = ['fraudster_event', 'fraudster']
    df[col] = df[col].apply(lambda x: x in fraud_descriptors)
    df[col].replace(True, int(1), inplace = True)
    return df

# %%
is_fraud(df, 'acct_type')
# Out:
#     acct_type  approx_payout_date  body_length  channels country currency  \
# 0         1.0          1266062400         3852         5      US      USD
# 1         0.0          1296720000         3499         0      US      USD
# 2         0.0          1296172800         2601         8      US      USD
# 3         0.0          1388966400        12347         6      IE      EUR
# 4         0.0          1297900800         2417        11      US      USD
# ..        ...                 ...          ...       ...     ...      ...
# 95        0.0          1328070600         1314         6      US      USD
# 96        0.0          1324098000         1483         6      US      USD
# 97        0.0          1325844000         1860         5      US      USD
# 98        0.0          1325836500         2219        11      US      USD
# 99        0.0          1357466400        12479         8      US      USD
#
#     delivery_method                                        description  \
# 0                 0  <p><a href="http://s432.photobucket.com/albums...
# 1                 1  <p>Join us for a quick, one-night, community-b...
# 2                 1  <h3><span class="subcategory"><strong>Teacher ...
# 3                 1  <p style="margin-bottom: 1.3em; padding-bottom...
# 4                 0  <p>Writers and filmmakers need to understand t...
# ..              ...                                                ...
# 95                0  <h3>Jan 26 at 7pm</h3>\r\n<h4>Opening Night Ga...
# 96                0  <p> </p>\r\n<div style="text-align: -webkit-au...
# 97                1  <p style="text-align: center;"><span style="fo...
# 98                1  <p style="font-size: 10pt;" align="left"><img ...
# 99                0  <p class="MsoNormal" style="text-align: center...
#
#                   email_domain  event_created  ...  \
# 0                    gmail.com     1262739706  ...
# 1                      ruf.org     1293832670  ...
# 2               pvsd.k12.ca.us     1291090956  ...
# 3         irishtabletennis.com     1360681570  ...
# 4   artsandbusinesscouncil.org     1291994666  ...
# ..                         ...            ...  ...
# 95             nwfilmforum.org     1322877746  ...
# 96         richmondicezone.com     1322879399  ...
# 97           kineticevents.com     1323477465  ...
# 98                   cecnc.com     1325106030  ...
# 99                     aol.com     1352996234  ...
#
#                                          ticket_types  user_age  user_created  \
# 0   [{'event_id': 527017, 'cost': 25.0, 'availabil...        36    1259613950
# 1   [{'event_id': 786878, 'cost': 35.0, 'availabil...       149    1280942776
# 2   [{'event_id': 787337, 'cost': 93.51, 'availabi...       214    1272559388
# 3   [{'event_id': 885645, 'cost': 25.0, 'availabil...       889    1283870102
# 4   [{'event_id': 1114349, 'cost': 150.0, 'availab...        35    1288984065
# ..                                                ...       ...           ...
# 95  [{'event_id': 2589534, 'cost': 38.0, 'availabi...       211    1304619530
# 96  [{'event_id': 2589614, 'cost': 8.0, 'availabil...       682    1263930774
# 97  [{'event_id': 2621588, 'cost': 20.0, 'availabi...       359    1292438475
# 98  [{'event_id': 2687671, 'cost': 0.0, 'availabil...       919    1245718455
# 99  [{'event_id': 2687765, 'cost': 20.0, 'availabi...      1103    1257709022
#
#     user_type                 venue_address  venue_country  venue_latitude  \
# 0           1         717 Washington Avenue             US       25.777471
# 1           3                                           US       32.776566
# 2           3  10100 Pioneer Blvd Suite 100             US       33.944201
# 3           3                                         None             NaN
# 4           3        One Marina Park Drive              US       42.353848
# ..        ...                           ...            ...             ...
# 95          3             1515 12th Avenue              US       47.614380
# 96          4       4350 Pouncey Tract Road             US       37.654891
# 97          1                 138 Minna St.             US       37.786823
# 98          3                  111 Minna St             US       37.787429
# 99          4     58 ROSS WAY QUINCY CENTER             US       42.247811
#
#     venue_longitude                              venue_name venue_state
# 0        -80.133433             INK Nightclub - South Beach          FL
# 1        -79.930922                 The Charleston, SC area          SC
# 2       -118.080419  Los Angeles County Office of Education          CA
# 3               NaN                                    None        None
# 4        -71.044276                       Fish & Richardson          MA
# ..              ...                                     ...         ...
# 95      -122.317031                   Northwest Film Forum           WA
# 96       -77.613550                        SkateNation Plus          VA
# 97      -122.400339                             John Colins          CA
# 98      -122.399384                       111 Minna Gallery          CA
# 99       -71.001400           CLUB 58 ENTERTAINMENT COMPLEX          MA
#
# [100 rows x 44 columns]

# %%
df['column_subset']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column_subset'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-06fa1cc4c5de> in <module>
# ----> 1 df['column_subset']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column_subset'

# %%
#make sure have values in test data - sam sent out link
'''
'has_analytics' - yes
'has_header' - yes
'has_logo' - yes
'listed' - yes
'name' - yes
'name_length' - yes
'num_order' - yes
'num_payouts' - yes
'object_id' - yes
'org_desc' - yes, but empty
'org_facebook' - yes
'org_name' - yes
'org_twitter' - yes
'payee_name' - yes, but empty 
'payout_type' - yes
'''
print('test')
# Out:
# test
